# %%
# ============================================================
# MODEL 9: InceptionV3
# ============================================================

# !pip -q install scikit-learn

import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers, models
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

# 1) Dataset Paths (Already split)
TRAIN_DIR = "/content/drive/MyDrive/Capstone Dataset/Guava_Leaf_Dieases/Train"
TEST_DIR  = "/content/drive/MyDrive/Capstone Dataset/Guava_Leaf_Dieases/Test"

# 2) Training Config
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42
EPOCHS_HEAD = 5
EPOCHS_FINETUNE = 25
LR_HEAD = 1e-3
LR_FINETUNE = 1e-5

# 3) Load Dataset (Train/Test)
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=True
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=False
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=False
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# 4) Check Class Match
if val_ds.class_names != class_names:
    raise ValueError(f"Class mismatch.\nTrain: {class_names}\nTest : {val_ds.class_names}")

# 5) Data Pipeline Optimization
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000, seed=SEED).prefetch(AUTOTUNE)
val_ds   = val_ds.cache().prefetch(AUTOTUNE)
test_ds  = test_ds.cache().prefetch(AUTOTUNE)

# 6) Data Augmentation
data_aug = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.15),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.1),
])

# 7) Build Model (Base + Head)
base = InceptionV3(include_top=False, weights="imagenet", input_shape=IMG_SIZE + (3,))
base.trainable = False

inputs = layers.Input(shape=IMG_SIZE + (3,))
x = data_aug(inputs)
x = preprocess_input(x)
x = base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.30)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)
model = models.Model(inputs, outputs)

# 8) Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=2, factor=0.5),
]

# 9) Train Head (Frozen Base)
model.compile(
    optimizer=tf.keras.optimizers.Adam(LR_HEAD),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
h1 = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_HEAD, callbacks=callbacks)

# 10) Fine-tuning (Unfreeze Last Layers)
base.trainable = True
for layer in base.layers[:-30]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(LR_FINETUNE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
h2 = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_FINETUNE, callbacks=callbacks)

# 11) Plot Training Curves
def plot_curves(h1, h2):
    acc = h1.history["accuracy"] + h2.history["accuracy"]
    val_acc = h1.history["val_accuracy"] + h2.history["val_accuracy"]
    loss = h1.history["loss"] + h2.history["loss"]
    val_loss = h1.history["val_loss"] + h2.history["val_loss"]

    plt.figure()
    plt.plot(acc, label="train_acc")
    plt.plot(val_acc, label="val_acc")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

    plt.figure()
    plt.plot(loss, label="train_loss")
    plt.plot(val_loss, label="val_loss")
    plt.title("Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

plot_curves(h1, h2)

# 12) Evaluate on Test
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"\nTest Accuracy: {test_acc:.4f} | Test Loss: {test_loss:.4f}")

# 13) Predictions
y_true = np.concatenate([y.numpy() for _, y in test_ds], axis=0)
y_prob = model.predict(test_ds, verbose=0)
y_pred = np.argmax(y_prob, axis=1)

# 14) Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# 15) Confusion Matrix (Blue style like your image, NO colorbar)
cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(7, 5))
ax.imshow(cm, cmap=plt.cm.Blues)
ax.set_title("Confusion Matrix", fontsize=18, pad=15)
ax.set_xlabel("Predicted label")
ax.set_ylabel("True label")
ax.set_xticks(range(num_classes))
ax.set_yticks(range(num_classes))
ax.set_xticklabels(class_names, rotation=45, ha="right")
ax.set_yticklabels(class_names)

thresh = cm.max() / 2.0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha="center", va="center",
                fontsize=14, color="white" if cm[i, j] > thresh else "black")

ax.grid(False)
plt.tight_layout()
plt.show()

# 16) ROC Curve (OvR)
y_true_bin = label_binarize(y_true, classes=list(range(num_classes)))
plt.figure()
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_names[i]} (AUC={roc_auc:.3f})")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curve (OvR)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.tight_layout()
plt.show()

# 17) Save Model
import os
os.makedirs("/content/drive/MyDrive/Capstone Models", exist_ok=True)

model.save("/content/drive/MyDrive/Capstone Models/InceptionV3_leaf.keras")
print("Model saved successfully.")
# Out:
# Found 4600 files belonging to 5 classes.
# Found 1150 files belonging to 5 classes.
# Found 1150 files belonging to 5 classes.
# Classes: ['Anthracnose', 'Canker', 'Dot', 'Healthy', 'Rust']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1604s 6s/step - accuracy: 0.4069 - loss: 1.4815 - val_accuracy: 0.6096 - val_loss: 1.0476 - learning_rate: 0.0010
# Epoch 2/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 793s 6s/step - accuracy: 0.6724 - loss: 0.8761 - val_accuracy: 0.6374 - val_loss: 0.9813 - learning_rate: 0.0010
# Epoch 3/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 849s 6s/step - accuracy: 0.7151 - loss: 0.7685 - val_accuracy: 0.6530 - val_loss: 0.9721 - learning_rate: 0.0010
# Epoch 4/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 850s 6s/step - accuracy: 0.7335 - loss: 0.7264 - val_accuracy: 0.6261 - val_loss: 1.0020 - learning_rate: 0.0010
# Epoch 5/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 797s 6s/step - accuracy: 0.7640 - loss: 0.6559 - val_accuracy: 0.6443 - val_loss: 0.9575 - learning_rate: 0.0010
# Epoch 1/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 952s 6s/step - accuracy: 0.6910 - loss: 0.8979 - val_accuracy: 0.6557 - val_loss: 0.9727 - learning_rate: 1.0000e-05
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 914s 6s/step - accuracy: 0.7807 - loss: 0.6018 - val_accuracy: 0.6470 - val_loss: 0.9405 - learning_rate: 1.0000e-05
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 907s 6s/step - accuracy: 0.7943 - loss: 0.5763 - val_accuracy: 0.6826 - val_loss: 0.8881 - learning_rate: 1.0000e-05
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 899s 6s/step - accuracy: 0.8293 - loss: 0.4849 - val_accuracy: 0.6878 - val_loss: 0.8785 - learning_rate: 1.0000e-05
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 946s 7s/step - accuracy: 0.8347 - loss: 0.4778 - val_accuracy: 0.6896 - val_loss: 0.8712 - learning_rate: 1.0000e-05
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 906s 6s/step - accuracy: 0.8354 - loss: 0.4636 - val_accuracy: 0.7078 - val_loss: 0.8478 - learning_rate: 1.0000e-05
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 886s 6s/step - accuracy: 0.8615 - loss: 0.4079 - val_accuracy: 0.7104 - val_loss: 0.8580 - learning_rate: 1.0000e-05
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 918s 6s/step - accuracy: 0.8605 - loss: 0.3993 - val_accuracy: 0.7148 - val_loss: 0.8635 - learning_rate: 1.0000e-05
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 913s 6s/step - accuracy: 0.8844 - loss: 0.3515 - val_accuracy: 0.7130 - val_loss: 0.8549 - learning_rate: 5.0000e-06
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 946s 7s/step - accuracy: 0.8807 - loss: 0.3538 - val_accuracy: 0.7165 - val_loss: 0.8481 - learning_rate: 5.0000e-06
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 954s 7s/step - accuracy: 0.8865 - loss: 0.3318 - val_accuracy: 0.7157 - val_loss: 0.8475 - learning_rate: 2.5000e-06
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1010s 7s/step - accuracy: 0.8921 - loss: 0.3213 - val_accuracy: 0.7157 - val_loss: 0.8471 - learning_rate: 2.5000e-06
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 933s 6s/step - accuracy: 0.8960 - loss: 0.3300 - val_accuracy: 0.7183 - val_loss: 0.8527 - learning_rate: 2.5000e-06
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 897s 6s/step - accuracy: 0.8918 - loss: 0.3231 - val_accuracy: 0.7200 - val_loss: 0.8526 - learning_rate: 2.5000e-06
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 904s 6s/step - accuracy: 0.8820 - loss: 0.3382 - val_accuracy: 0.7191 - val_loss: 0.8479 - learning_rate: 1.2500e-06
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 919s 6s/step - accuracy: 0.8966 - loss: 0.3079 - val_accuracy: 0.7183 - val_loss: 0.8488 - learning_rate: 1.2500e-06
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 891s 6s/step - accuracy: 0.8864 - loss: 0.3233 - val_accuracy: 0.7174 - val_loss: 0.8466 - learning_rate: 6.2500e-07
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 961s 7s/step - accuracy: 0.8973 - loss: 0.3047 - val_accuracy: 0.7191 - val_loss: 0.8483 - learning_rate: 6.2500e-07
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 919s 6s/step - accuracy: 0.8978 - loss: 0.3123 - val_accuracy: 0.7174 - val_loss: 0.8472 - learning_rate: 6.2500e-07
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 918s 6s/step - accuracy: 0.8962 - loss: 0.3089 - val_accuracy: 0.7200 - val_loss: 0.8462 - learning_rate: 3.1250e-07
# Epoch 21/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 918s 6s/step - accuracy: 0.9010 - loss: 0.3152 - val_accuracy: 0.7191 - val_loss: 0.8457 - learning_rate: 3.1250e-07
# Epoch 22/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 935s 6s/step - accuracy: 0.9023 - loss: 0.2998 - val_accuracy: 0.7174 - val_loss: 0.8458 - learning_rate: 3.1250e-07
# Epoch 23/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 904s 6s/step - accuracy: 0.8968 - loss: 0.3155 - val_accuracy: 0.7200 - val_loss: 0.8452 - learning_rate: 3.1250e-07
# Epoch 24/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 948s 6s/step - accuracy: 0.9028 - loss: 0.3075 - val_accuracy: 0.7200 - val_loss: 0.8439 - learning_rate: 3.1250e-07
# Epoch 25/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1008s 7s/step - accuracy: 0.8969 - loss: 0.3028 - val_accuracy: 0.7200 - val_loss: 0.8437 - learning_rate: 3.1250e-07
# Test Accuracy: 0.7200 | Test Loss: 0.8437
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Anthracnose     0.6555    0.8522    0.7410       230
#       Canker     0.8086    0.7348    0.7699       230
#          Dot     0.6087    0.4870    0.5411       230
#      Healthy     0.7232    0.9087    0.8054       230
#         Rust     0.8402    0.6174    0.7118       230
#
#     accuracy                         0.7200      1150
#    macro avg     0.7272    0.7200    0.7138      1150
# weighted avg     0.7272    0.7200    0.7138      1150
# Model saved successfully.
