# %%
# ============================================================
# MODEL 8: Xception
# ============================================================

# !pip -q install scikit-learn

import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers, models
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications.xception import preprocess_input
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

# %%
# 1) Dataset Paths (Already split)
TRAIN_DIR = "/content/drive/MyDrive/Capstone Dataset/Guava_Leaf_Dieases/Train"
TEST_DIR  = "/content/drive/MyDrive/Capstone Dataset/Guava_Leaf_Dieases/Test"

# %%
# 2) Training Config
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42
EPOCHS_HEAD = 5
EPOCHS_FINETUNE = 25
LR_HEAD = 1e-3
LR_FINETUNE = 1e-5

# %%
# 3) Load Dataset (Train/Test)
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=True
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=False
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=False
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)
# Out:
# Found 4600 files belonging to 5 classes.
# Found 1150 files belonging to 5 classes.
# Found 1150 files belonging to 5 classes.
# Classes: ['Anthracnose', 'Canker', 'Dot', 'Healthy', 'Rust']

# %%
# 4) Check Class Match
if val_ds.class_names != class_names:
    raise ValueError(f"Class mismatch.\nTrain: {class_names}\nTest : {val_ds.class_names}")

# %%
# 5) Data Pipeline Optimization
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000, seed=SEED).prefetch(AUTOTUNE)
val_ds   = val_ds.cache().prefetch(AUTOTUNE)
test_ds  = test_ds.cache().prefetch(AUTOTUNE)

# %%
# 6) Data Augmentation
data_aug = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.15),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.1),
])

# %%
# 7) Build Model (Base + Head)
base = Xception(include_top=False, weights="imagenet", input_shape=IMG_SIZE + (3,))
base.trainable = False

inputs = layers.Input(shape=IMG_SIZE + (3,))
x = data_aug(inputs)
x = preprocess_input(x)
x = base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.30)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)
model = models.Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# 8) Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=2, factor=0.5),
]

# %%
# 9) Train Head (Frozen Base)
model.compile(
    optimizer=tf.keras.optimizers.Adam(LR_HEAD),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
h1 = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_HEAD, callbacks=callbacks)
# Out:
# Epoch 1/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 978s 2s/step - accuracy: 0.4589 - loss: 1.3003 - val_accuracy: 0.5870 - val_loss: 1.0877 - learning_rate: 0.0010
# Epoch 2/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 28s 192ms/step - accuracy: 0.6923 - loss: 0.8337 - val_accuracy: 0.6174 - val_loss: 1.0345 - learning_rate: 0.0010
# Epoch 3/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 28s 197ms/step - accuracy: 0.7516 - loss: 0.7215 - val_accuracy: 0.6270 - val_loss: 1.0144 - learning_rate: 0.0010
# Epoch 4/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 29s 202ms/step - accuracy: 0.7642 - loss: 0.6706 - val_accuracy: 0.6322 - val_loss: 0.9939 - learning_rate: 0.0010
# Epoch 5/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 31s 214ms/step - accuracy: 0.7895 - loss: 0.6198 - val_accuracy: 0.6426 - val_loss: 0.9896 - learning_rate: 0.0010

# %%
# 10) Fine-tuning (Unfreeze Last Layers)
base.trainable = True
for layer in base.layers[:-30]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(LR_FINETUNE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
h2 = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_FINETUNE, callbacks=callbacks)
# Out:
# Epoch 1/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 59s 343ms/step - accuracy: 0.5684 - loss: 1.1494 - val_accuracy: 0.6243 - val_loss: 1.1185 - learning_rate: 1.0000e-05
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 77s 322ms/step - accuracy: 0.7667 - loss: 0.6803 - val_accuracy: 0.6443 - val_loss: 0.9592 - learning_rate: 1.0000e-05
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 45s 312ms/step - accuracy: 0.8134 - loss: 0.5380 - val_accuracy: 0.6739 - val_loss: 0.8911 - learning_rate: 1.0000e-05
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 47s 325ms/step - accuracy: 0.8524 - loss: 0.4419 - val_accuracy: 0.6783 - val_loss: 0.8636 - learning_rate: 1.0000e-05
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 79s 302ms/step - accuracy: 0.8709 - loss: 0.3816 - val_accuracy: 0.6887 - val_loss: 0.8650 - learning_rate: 1.0000e-05
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 43s 299ms/step - accuracy: 0.8801 - loss: 0.3381 - val_accuracy: 0.6983 - val_loss: 0.8593 - learning_rate: 1.0000e-05
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 44s 304ms/step - accuracy: 0.9056 - loss: 0.2859 - val_accuracy: 0.7139 - val_loss: 0.8382 - learning_rate: 1.0000e-05
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 43s 301ms/step - accuracy: 0.9144 - loss: 0.2654 - val_accuracy: 0.7130 - val_loss: 0.8352 - learning_rate: 1.0000e-05
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 44s 303ms/step - accuracy: 0.9192 - loss: 0.2356 - val_accuracy: 0.7278 - val_loss: 0.8312 - learning_rate: 1.0000e-05
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 46s 320ms/step - accuracy: 0.9336 - loss: 0.2098 - val_accuracy: 0.7296 - val_loss: 0.8240 - learning_rate: 1.0000e-05
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 45s 314ms/step - accuracy: 0.9387 - loss: 0.1858 - val_accuracy: 0.7339 - val_loss: 0.8340 - learning_rate: 1.0000e-05
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 46s 323ms/step - accuracy: 0.9488 - loss: 0.1635 - val_accuracy: 0.7243 - val_loss: 0.8563 - learning_rate: 1.0000e-05
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 45s 313ms/step - accuracy: 0.9552 - loss: 0.1591 - val_accuracy: 0.7270 - val_loss: 0.8646 - learning_rate: 5.0000e-06
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 46s 321ms/step - accuracy: 0.9506 - loss: 0.1504 - val_accuracy: 0.7357 - val_loss: 0.8701 - learning_rate: 5.0000e-06
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 46s 319ms/step - accuracy: 0.9545 - loss: 0.1481 - val_accuracy: 0.7357 - val_loss: 0.8642 - learning_rate: 2.5000e-06

# %%
# 11) Plot Training Curves
def plot_curves(h1, h2):
    acc = h1.history["accuracy"] + h2.history["accuracy"]
    val_acc = h1.history["val_accuracy"] + h2.history["val_accuracy"]
    loss = h1.history["loss"] + h2.history["loss"]
    val_loss = h1.history["val_loss"] + h2.history["val_loss"]

    plt.figure()
    plt.plot(acc, label="train_acc")
    plt.plot(val_acc, label="val_acc")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

    plt.figure()
    plt.plot(loss, label="train_loss")
    plt.plot(val_loss, label="val_loss")
    plt.title("Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

plot_curves(h1, h2)

# %%
# 12) Evaluate on Test
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"\nTest Accuracy: {test_acc:.4f} | Test Loss: {test_loss:.4f}")
# Out:
# Test Accuracy: 0.7296 | Test Loss: 0.8240

# %%
# 13) Predictions
y_true = np.concatenate([y.numpy() for _, y in test_ds], axis=0)
y_prob = model.predict(test_ds, verbose=0)
y_pred = np.argmax(y_prob, axis=1)

# %%
# 14) Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#  Anthracnose     0.6633    0.8652    0.7509       230
#       Canker     0.8117    0.7870    0.7991       230
#          Dot     0.5724    0.3783    0.4555       230
#      Healthy     0.7420    0.9130    0.8187       230
#         Rust     0.8438    0.7043    0.7678       230
#
#     accuracy                         0.7296      1150
#    macro avg     0.7266    0.7296    0.7184      1150
# weighted avg     0.7266    0.7296    0.7184      1150

# %%
# 15) Confusion Matrix (Blue style like your image, NO colorbar)
cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(7, 5))
ax.imshow(cm, cmap=plt.cm.Blues)
ax.set_title("Confusion Matrix", fontsize=18, pad=15)
ax.set_xlabel("Predicted label")
ax.set_ylabel("True label")
ax.set_xticks(range(num_classes))
ax.set_yticks(range(num_classes))
ax.set_xticklabels(class_names, rotation=45, ha="right")
ax.set_yticklabels(class_names)

thresh = cm.max() / 2.0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha="center", va="center",
                fontsize=14, color="white" if cm[i, j] > thresh else "black")

ax.grid(False)
plt.tight_layout()
plt.show()

# %%
# 16) ROC Curve (OvR)
y_true_bin = label_binarize(y_true, classes=list(range(num_classes)))
plt.figure()
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_names[i]} (AUC={roc_auc:.3f})")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curve (OvR)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# 17) Save Model
import os
os.makedirs("/content/drive/MyDrive/Capstone Models", exist_ok=True)

model.save("/content/drive/MyDrive/Capstone Models/Xception_leaf.keras")
print("Model saved successfully.")
# Out:
# Model saved successfully.
