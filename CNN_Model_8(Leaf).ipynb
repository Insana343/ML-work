# %%
# ============================================================
# MODEL 4: DenseNet121
# ============================================================

# !pip -q install scikit-learn

import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers, models
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

# 1) Dataset Paths (Already split)
TRAIN_DIR = "/content/drive/MyDrive/Capstone Dataset/Guava_Leaf_Dieases/Train"
TEST_DIR  = "/content/drive/MyDrive/Capstone Dataset/Guava_Leaf_Dieases/Test"

# 2) Training Config
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42
EPOCHS_HEAD = 5
EPOCHS_FINETUNE = 25
LR_HEAD = 1e-3
LR_FINETUNE = 1e-5

# 3) Load Dataset (Train/Test)
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=True
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=False
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=False
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# 4) Check Class Match
if val_ds.class_names != class_names:
    raise ValueError(f"Class mismatch.\nTrain: {class_names}\nTest : {val_ds.class_names}")

# 5) Data Pipeline Optimization
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000, seed=SEED).prefetch(AUTOTUNE)
val_ds   = val_ds.cache().prefetch(AUTOTUNE)
test_ds  = test_ds.cache().prefetch(AUTOTUNE)

# 6) Data Augmentation
data_aug = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.15),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.1),
])

# 7) Build Model (Base + Head)
base = DenseNet121(include_top=False, weights="imagenet", input_shape=IMG_SIZE + (3,))
base.trainable = False

inputs = layers.Input(shape=IMG_SIZE + (3,))
x = data_aug(inputs)
x = preprocess_input(x)
x = base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.30)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)
model = models.Model(inputs, outputs)

# 8) Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=2, factor=0.5),
]

# 9) Train Head (Frozen Base)
model.compile(
    optimizer=tf.keras.optimizers.Adam(LR_HEAD),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
h1 = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_HEAD, callbacks=callbacks)

# 10) Fine-tuning (Unfreeze Last Layers)
base.trainable = True
for layer in base.layers[:-30]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(LR_FINETUNE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
h2 = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_FINETUNE, callbacks=callbacks)

# 11) Plot Training Curves
def plot_curves(h1, h2):
    acc = h1.history["accuracy"] + h2.history["accuracy"]
    val_acc = h1.history["val_accuracy"] + h2.history["val_accuracy"]
    loss = h1.history["loss"] + h2.history["loss"]
    val_loss = h1.history["val_loss"] + h2.history["val_loss"]

    plt.figure()
    plt.plot(acc, label="train_acc")
    plt.plot(val_acc, label="val_acc")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

    plt.figure()
    plt.plot(loss, label="train_loss")
    plt.plot(val_loss, label="val_loss")
    plt.title("Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

plot_curves(h1, h2)

# 12) Evaluate on Test
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"\nTest Accuracy: {test_acc:.4f} | Test Loss: {test_loss:.4f}")

# 13) Predictions
y_true = np.concatenate([y.numpy() for _, y in test_ds], axis=0)
y_prob = model.predict(test_ds, verbose=0)
y_pred = np.argmax(y_prob, axis=1)

# 14) Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# 15) Confusion Matrix (Blue style like your image, NO colorbar)
cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(7, 5))
ax.imshow(cm, cmap=plt.cm.Blues)
ax.set_title("Confusion Matrix", fontsize=18, pad=15)
ax.set_xlabel("Predicted label")
ax.set_ylabel("True label")
ax.set_xticks(range(num_classes))
ax.set_yticks(range(num_classes))
ax.set_xticklabels(class_names, rotation=45, ha="right")
ax.set_yticklabels(class_names)

thresh = cm.max() / 2.0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha="center", va="center",
                fontsize=14, color="white" if cm[i, j] > thresh else "black")

ax.grid(False)
plt.tight_layout()
plt.show()

# 16) ROC Curve (OvR)
y_true_bin = label_binarize(y_true, classes=list(range(num_classes)))
plt.figure()
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_names[i]} (AUC={roc_auc:.3f})")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curve (OvR)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.tight_layout()
plt.show()

# 17) Save Model
import os
os.makedirs("/content/drive/MyDrive/Capstone Models", exist_ok=True)

model.save("/content/drive/MyDrive/Capstone Models/DenseNet121_leaf.keras")
print("Model saved successfully.")
# Out:
# Found 4600 files belonging to 5 classes.
# Found 1150 files belonging to 5 classes.
# Found 1150 files belonging to 5 classes.
# Classes: ['Anthracnose', 'Canker', 'Dot', 'Healthy', 'Rust']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 662s 1s/step - accuracy: 0.3633 - loss: 1.6020 - val_accuracy: 0.6591 - val_loss: 0.9341 - learning_rate: 0.0010
# Epoch 2/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 26s 183ms/step - accuracy: 0.6743 - loss: 0.8781 - val_accuracy: 0.7191 - val_loss: 0.8194 - learning_rate: 0.0010
# Epoch 3/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 26s 180ms/step - accuracy: 0.7354 - loss: 0.7073 - val_accuracy: 0.7217 - val_loss: 0.7895 - learning_rate: 0.0010
# Epoch 4/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 26s 180ms/step - accuracy: 0.7786 - loss: 0.6271 - val_accuracy: 0.7217 - val_loss: 0.7848 - learning_rate: 0.0010
# Epoch 5/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 26s 180ms/step - accuracy: 0.7807 - loss: 0.5948 - val_accuracy: 0.7383 - val_loss: 0.7601 - learning_rate: 0.0010
# Epoch 1/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 51s 230ms/step - accuracy: 0.5093 - loss: 2.0410 - val_accuracy: 0.6391 - val_loss: 1.0031 - learning_rate: 1.0000e-05
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 190ms/step - accuracy: 0.6148 - loss: 1.3790 - val_accuracy: 0.6304 - val_loss: 1.1457 - learning_rate: 1.0000e-05
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 188ms/step - accuracy: 0.6640 - loss: 1.1379 - val_accuracy: 0.6548 - val_loss: 1.0511 - learning_rate: 1.0000e-05
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 190ms/step - accuracy: 0.7191 - loss: 0.9282 - val_accuracy: 0.6696 - val_loss: 0.9955 - learning_rate: 5.0000e-06
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 190ms/step - accuracy: 0.7302 - loss: 0.8633 - val_accuracy: 0.6861 - val_loss: 0.9507 - learning_rate: 5.0000e-06
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 41s 190ms/step - accuracy: 0.7475 - loss: 0.7807 - val_accuracy: 0.7052 - val_loss: 0.9112 - learning_rate: 5.0000e-06
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 28s 192ms/step - accuracy: 0.7588 - loss: 0.7239 - val_accuracy: 0.7200 - val_loss: 0.8895 - learning_rate: 5.0000e-06
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 189ms/step - accuracy: 0.7667 - loss: 0.6904 - val_accuracy: 0.7261 - val_loss: 0.8675 - learning_rate: 5.0000e-06
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 41s 190ms/step - accuracy: 0.7824 - loss: 0.6274 - val_accuracy: 0.7278 - val_loss: 0.8597 - learning_rate: 5.0000e-06
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 28s 192ms/step - accuracy: 0.7847 - loss: 0.6355 - val_accuracy: 0.7348 - val_loss: 0.8456 - learning_rate: 5.0000e-06
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 188ms/step - accuracy: 0.7793 - loss: 0.6223 - val_accuracy: 0.7374 - val_loss: 0.8438 - learning_rate: 5.0000e-06
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 189ms/step - accuracy: 0.8028 - loss: 0.5823 - val_accuracy: 0.7426 - val_loss: 0.8338 - learning_rate: 5.0000e-06
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 190ms/step - accuracy: 0.8019 - loss: 0.5685 - val_accuracy: 0.7426 - val_loss: 0.8315 - learning_rate: 5.0000e-06
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 190ms/step - accuracy: 0.7923 - loss: 0.5836 - val_accuracy: 0.7487 - val_loss: 0.8289 - learning_rate: 5.0000e-06
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 189ms/step - accuracy: 0.8145 - loss: 0.5344 - val_accuracy: 0.7504 - val_loss: 0.8272 - learning_rate: 5.0000e-06
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 190ms/step - accuracy: 0.8071 - loss: 0.5369 - val_accuracy: 0.7539 - val_loss: 0.8182 - learning_rate: 5.0000e-06
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 188ms/step - accuracy: 0.8123 - loss: 0.5254 - val_accuracy: 0.7583 - val_loss: 0.8216 - learning_rate: 5.0000e-06
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 188ms/step - accuracy: 0.8202 - loss: 0.4932 - val_accuracy: 0.7557 - val_loss: 0.8196 - learning_rate: 5.0000e-06
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 189ms/step - accuracy: 0.8192 - loss: 0.5079 - val_accuracy: 0.7548 - val_loss: 0.8212 - learning_rate: 2.5000e-06
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 188ms/step - accuracy: 0.8301 - loss: 0.4750 - val_accuracy: 0.7565 - val_loss: 0.8246 - learning_rate: 2.5000e-06
# Epoch 21/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 189ms/step - accuracy: 0.8392 - loss: 0.4804 - val_accuracy: 0.7565 - val_loss: 0.8181 - learning_rate: 1.2500e-06
# Epoch 22/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 189ms/step - accuracy: 0.8214 - loss: 0.4972 - val_accuracy: 0.7574 - val_loss: 0.8272 - learning_rate: 1.2500e-06
# Epoch 23/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 188ms/step - accuracy: 0.8373 - loss: 0.4761 - val_accuracy: 0.7574 - val_loss: 0.8184 - learning_rate: 1.2500e-06
# Epoch 24/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 190ms/step - accuracy: 0.8287 - loss: 0.4920 - val_accuracy: 0.7574 - val_loss: 0.8203 - learning_rate: 6.2500e-07
# Epoch 25/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 188ms/step - accuracy: 0.8172 - loss: 0.4807 - val_accuracy: 0.7574 - val_loss: 0.8242 - learning_rate: 6.2500e-07
# Test Accuracy: 0.7565 | Test Loss: 0.8181
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Anthracnose     0.6902    0.8913    0.7780       230
#       Canker     0.8502    0.8391    0.8446       230
#          Dot     0.7016    0.3783    0.4915       230
#      Healthy     0.7036    0.9391    0.8045       230
#         Rust     0.8667    0.7348    0.7953       230
#
#     accuracy                         0.7565      1150
#    macro avg     0.7625    0.7565    0.7428      1150
# weighted avg     0.7625    0.7565    0.7428      1150
# Model saved successfully.
