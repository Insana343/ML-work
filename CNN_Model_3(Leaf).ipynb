# %%
# MODEL 2: EfficientNetB3
# ============================================================

# !pip -q install scikit-learn

import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.applications.efficientnet import preprocess_input
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

# %%
# 1) Dataset Paths (Already split)
TRAIN_DIR = "/content/drive/MyDrive/Capstone Dataset/Guava_Leaf_Dieases/Train"
TEST_DIR  = "/content/drive/MyDrive/Capstone Dataset/Guava_Leaf_Dieases/Test"

# %%
# 2) Training Config
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42
EPOCHS_HEAD = 5
EPOCHS_FINETUNE = 25
LR_HEAD = 1e-3
LR_FINETUNE = 1e-5

# %%
# 3) Load Dataset (Train/Test)
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=True
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=False
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR, seed=SEED, image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    label_mode="int", shuffle=False
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)
# Out:
# Found 4600 files belonging to 5 classes.
# Found 1150 files belonging to 5 classes.
# Found 1150 files belonging to 5 classes.
# Classes: ['Anthracnose', 'Canker', 'Dot', 'Healthy', 'Rust']

# %%
# 4) Check Class Match
if val_ds.class_names != class_names:
    raise ValueError(f"Class mismatch.\nTrain: {class_names}\nTest : {val_ds.class_names}")

# %%
# 5) Data Pipeline Optimization
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000, seed=SEED).prefetch(AUTOTUNE)
val_ds   = val_ds.cache().prefetch(AUTOTUNE)
test_ds  = test_ds.cache().prefetch(AUTOTUNE)

# %%
# 6) Data Augmentation
data_aug = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.15),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.1),
])

# %%
# 7) Build Model (Base + Head)
base = EfficientNetB3(include_top=False, weights="imagenet", input_shape=IMG_SIZE + (3,))
base.trainable = False

inputs = layers.Input(shape=IMG_SIZE + (3,))
x = data_aug(inputs)
x = preprocess_input(x)
x = base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.30)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)
model = models.Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# 8) Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=2, factor=0.5),
]

# %%
# 9) Train Head (Frozen Base)
model.compile(
    optimizer=tf.keras.optimizers.Adam(LR_HEAD),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
h1 = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_HEAD, callbacks=callbacks)
# Out:
# Epoch 1/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1002s 2s/step - accuracy: 0.4148 - loss: 1.3708 - val_accuracy: 0.6235 - val_loss: 1.0488 - learning_rate: 0.0010
# Epoch 2/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 28s 197ms/step - accuracy: 0.6658 - loss: 0.9001 - val_accuracy: 0.6643 - val_loss: 0.9368 - learning_rate: 0.0010
# Epoch 3/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 26s 184ms/step - accuracy: 0.7208 - loss: 0.7926 - val_accuracy: 0.6687 - val_loss: 0.9124 - learning_rate: 0.0010
# Epoch 4/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 26s 184ms/step - accuracy: 0.7310 - loss: 0.7470 - val_accuracy: 0.6870 - val_loss: 0.8525 - learning_rate: 0.0010
# Epoch 5/5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 27s 188ms/step - accuracy: 0.7538 - loss: 0.6924 - val_accuracy: 0.6783 - val_loss: 0.8378 - learning_rate: 0.0010

# %%
# 10) Fine-tuning (Unfreeze Last Layers)
base.trainable = True
for layer in base.layers[:-30]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(LR_FINETUNE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
h2 = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_FINETUNE, callbacks=callbacks)
# Out:
# Epoch 1/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 55s 241ms/step - accuracy: 0.6868 - loss: 0.8303 - val_accuracy: 0.6948 - val_loss: 0.8445 - learning_rate: 1.0000e-05
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 31s 215ms/step - accuracy: 0.7361 - loss: 0.7294 - val_accuracy: 0.7070 - val_loss: 0.8256 - learning_rate: 1.0000e-05
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 30s 208ms/step - accuracy: 0.7669 - loss: 0.6680 - val_accuracy: 0.7174 - val_loss: 0.7840 - learning_rate: 1.0000e-05
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 30s 210ms/step - accuracy: 0.7824 - loss: 0.6020 - val_accuracy: 0.7157 - val_loss: 0.7716 - learning_rate: 1.0000e-05
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 30s 210ms/step - accuracy: 0.7964 - loss: 0.5659 - val_accuracy: 0.7226 - val_loss: 0.7593 - learning_rate: 1.0000e-05
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 30s 208ms/step - accuracy: 0.8153 - loss: 0.5173 - val_accuracy: 0.7304 - val_loss: 0.7405 - learning_rate: 1.0000e-05
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 30s 208ms/step - accuracy: 0.8262 - loss: 0.5092 - val_accuracy: 0.7278 - val_loss: 0.7535 - learning_rate: 1.0000e-05
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 30s 208ms/step - accuracy: 0.8287 - loss: 0.4851 - val_accuracy: 0.7322 - val_loss: 0.7555 - learning_rate: 1.0000e-05
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 30s 208ms/step - accuracy: 0.8551 - loss: 0.4398 - val_accuracy: 0.7339 - val_loss: 0.7491 - learning_rate: 5.0000e-06
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 30s 209ms/step - accuracy: 0.8457 - loss: 0.4365 - val_accuracy: 0.7339 - val_loss: 0.7462 - learning_rate: 5.0000e-06
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 30s 208ms/step - accuracy: 0.8543 - loss: 0.4219 - val_accuracy: 0.7348 - val_loss: 0.7447 - learning_rate: 2.5000e-06

# %%
# 11) Plot Training Curves
def plot_curves(h1, h2):
    acc = h1.history["accuracy"] + h2.history["accuracy"]
    val_acc = h1.history["val_accuracy"] + h2.history["val_accuracy"]
    loss = h1.history["loss"] + h2.history["loss"]
    val_loss = h1.history["val_loss"] + h2.history["val_loss"]

    plt.figure()
    plt.plot(acc, label="train_acc")
    plt.plot(val_acc, label="val_acc")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

    plt.figure()
    plt.plot(loss, label="train_loss")
    plt.plot(val_loss, label="val_loss")
    plt.title("Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

plot_curves(h1, h2)

# %%
# 12) Evaluate on Test
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"\nTest Accuracy: {test_acc:.4f} | Test Loss: {test_loss:.4f}")
# Out:
# Test Accuracy: 0.7304 | Test Loss: 0.7405

# %%
# 13) Predictions
y_true = np.concatenate([y.numpy() for _, y in test_ds], axis=0)
y_prob = model.predict(test_ds, verbose=0)
y_pred = np.argmax(y_prob, axis=1)

# %%
# 14) Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#  Anthracnose     0.6440    0.8652    0.7384       230
#       Canker     0.8641    0.7739    0.8165       230
#          Dot     0.5690    0.4304    0.4901       230
#      Healthy     0.7201    0.8391    0.7751       230
#         Rust     0.8860    0.7435    0.8085       230
#
#     accuracy                         0.7304      1150
#    macro avg     0.7366    0.7304    0.7257      1150
# weighted avg     0.7366    0.7304    0.7257      1150

# %%
# 15) Confusion Matrix (Blue style like your image, NO colorbar)
cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(7, 5))
ax.imshow(cm, cmap=plt.cm.Blues)
ax.set_title("Confusion Matrix", fontsize=18, pad=15)
ax.set_xlabel("Predicted label")
ax.set_ylabel("True label")
ax.set_xticks(range(num_classes))
ax.set_yticks(range(num_classes))
ax.set_xticklabels(class_names, rotation=45, ha="right")
ax.set_yticklabels(class_names)

thresh = cm.max() / 2.0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha="center", va="center",
                fontsize=14, color="white" if cm[i, j] > thresh else "black")

ax.grid(False)
plt.tight_layout()
plt.show()

# %%
# 16) ROC Curve (OvR)
y_true_bin = label_binarize(y_true, classes=list(range(num_classes)))
plt.figure()
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_names[i]} (AUC={roc_auc:.3f})")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curve (OvR)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# 17) Save Model
import os
os.makedirs("/content/drive/MyDrive/Capstone Models", exist_ok=True)

model.save("/content/drive/MyDrive/Capstone Models/EfficientNetB3_leaf.keras")
print("Model saved successfully.")
# Out:
# Model saved successfully.
